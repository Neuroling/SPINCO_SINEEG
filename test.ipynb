# %% [markdown]
#  # MNE DEMO
#
#  ## Reading epochs
#
# We have an epoched object saved in a .fif file.

# %%
import mne 
fileinput = 'V:\spinco_data\SINEEG\DiN\data_preproc_ep_ICrem\epochs\s17_DiN_epoched_ICrem-epo.fif'
epochs = mne.read_epochs(fileinput)
# Out:
# Reading V:\spinco_data\SINEEG\DiN\data_preproc_ep_ICrem\epochs\s17_DiN_epoched_ICrem-epo.fif ...
#     Found the data of interest:
#         t =   -3335.00 ...    1960.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 320 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# # Visualizations
#
# MNE offers multiple ways of visualizing data. Some of them will pop-up an interactive plot. Static plots will be posted online
#
# ### Note on pop-up interactive plots
# Before launching this notebook you will need to install **nb_conda_kernels**  in your environment:
# ```` conda install nb_conda_kernels ```` .   Besides , before the plots you need the magic line:  ```` %matplotlib qt ````

# %%
# %matplotlib qt 
epochs.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Dropped 0 epochs:
# The following epochs were marked as bad and are dropped:
# []
# Channels marked as bad:
# none
